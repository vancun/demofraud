# %%
from demolib import schema, cfg, spark
from demolib.lib import *


from confluent_kafka import Producer
from time import sleep
from random import random
import json
import sys
import os
from pyspark.sql.functions import expr

# %%
raw_transaction_df = spark.read \
    .option('header', False) \
    .csv('{}/{}'.format(cfg.load.dir, cfg.load.event_transaction), schema=schema.transaction.schema)

transaction_df = raw_transaction_df.withColumn('trans_time', expr('current_timestamp()')) \
    .select("cc_num", "first", "last", "trans_num", "trans_time", "category", "merchant", "amt", "merch_lat", "merch_long")

# %%
transaction_list = transaction_df.collect()

# %%
def delivery_callback(err, msg):
    if err:
        sys.stderr.write('%% Message failed delivery: %s\n' % err)
    else:
        sys.stderr.write('%% Message delivered to %s [%d] @ %o\n' % (msg.topic(), msg.partition(), msg.offset()))

# %%
# See https://github.com/Azure/azure-event-hubs-for-kafka/tree/master/quickstart/python

# Create Producer instance
p = Producer(**cfg.kafka.config)

for i in range(0, len(transaction_list)):

    trans = transaction_list[i].asDict()
    trans['trans_time'] = str(trans['trans_time'])

    trans_json = json.dumps(trans)

    try:
        p.produce(cfg.kafka.topic, trans_json, callback=delivery_callback)
        p.poll(5)
    except BufferError as e:
        sys.stderr.write('%% Local producer queue is full (%d messages awaiting delivery): try again\n' % len(p))
    

    if flag_poll('producer_stop', True):
        sys.stderr.write('%% Producer %s stop requested!\n' % '')
        break

    sleep(random()*2.0 + 1.0)

# Wait until all messages have been delivered
sys.stderr.write('%% Waiting for %d deliveries\n' % len(p))
p.flush()
# Out:
# % Message delivered to ccfraud [0] @ 13756
# % Message delivered to ccfraud [0] @ 13757
# % Message delivered to ccfraud [0] @ 13760
# % Message delivered to ccfraud [0] @ 13761
# % Message delivered to ccfraud [0] @ 13762
# % Message delivered to ccfraud [0] @ 13763
# % Message delivered to ccfraud [0] @ 13764
# % Message delivered to ccfraud [0] @ 13765
# % Message delivered to ccfraud [0] @ 13766
# % Message delivered to ccfraud [0] @ 13767
# % Message delivered to ccfraud [0] @ 13770
# % Message delivered to ccfraud [0] @ 13771
# % Message delivered to ccfraud [0] @ 13772
# % Message delivered to ccfraud [0] @ 13773
# % Message delivered to ccfraud [0] @ 13774
# % Message delivered to ccfraud [0] @ 13775
# % Message delivered to ccfraud [0] @ 13776
# % Message delivered to ccfraud [0] @ 13777
# % Message delivered to ccfraud [0] @ 14000
# % Message delivered to ccfraud [0] @ 14001
# % Message delivered to ccfraud [0] @ 14002
# % Message delivered to ccfraud [0] @ 14003
# % Message delivered to ccfraud [0] @ 14004
# % Message delivered to ccfraud [0] @ 14005
# % Message delivered to ccfraud [0] @ 14006
# % Message delivered to ccfraud [0] @ 14007
# % Message delivered to ccfraud [0] @ 14010
# % Message delivered to ccfraud [0] @ 14011
# % Message delivered to ccfraud [0] @ 14012
# % Message delivered to ccfraud [0] @ 14013
# % Message delivered to ccfraud [0] @ 14014
# % Message delivered to ccfraud [0] @ 14015
# % Message delivered to ccfraud [0] @ 14016
# % Message delivered to ccfraud [0] @ 14017
# % Message delivered to ccfraud [0] @ 14020
# % Message delivered to ccfraud [0] @ 14021
# % Message delivered to ccfraud [0] @ 14022
# % Message delivered to ccfraud [0] @ 14023
# % Message delivered to ccfraud [0] @ 14024
# % Message delivered to ccfraud [0] @ 14025
# % Message delivered to ccfraud [0] @ 14026
# % Message delivered to ccfraud [0] @ 14027
# % Message delivered to ccfraud [0] @ 14030
# % Message delivered to ccfraud [0] @ 14031
# % Message delivered to ccfraud [0] @ 14032
# % Message delivered to ccfraud [0] @ 14033
# % Message delivered to ccfraud [0] @ 14034
# % Message delivered to ccfraud [0] @ 14035
# % Message delivered to ccfraud [0] @ 14036
# % Message delivered to ccfraud [0] @ 14037
# % Message delivered to ccfraud [0] @ 14040
# % Message delivered to ccfraud [0] @ 14041
# % Message delivered to ccfraud [0] @ 14042
# % Message delivered to ccfraud [0] @ 14043
# % Message delivered to ccfraud [0] @ 14044
# % Message delivered to ccfraud [0] @ 14045
# % Message delivered to ccfraud [0] @ 14046
# % Message delivered to ccfraud [0] @ 14047
# % Message delivered to ccfraud [0] @ 14050
# % Message delivered to ccfraud [0] @ 14051
# % Message delivered to ccfraud [0] @ 14052
# % Message delivered to ccfraud [0] @ 14053
# % Message delivered to ccfraud [0] @ 14054
# % Message delivered to ccfraud [0] @ 14055
# % Message delivered to ccfraud [0] @ 14056
# % Message delivered to ccfraud [0] @ 14057
# % Message delivered to ccfraud [0] @ 14060
# % Message delivered to ccfraud [0] @ 14061
# % Message delivered to ccfraud [0] @ 14062
# % Message delivered to ccfraud [0] @ 14063
# % Message delivered to ccfraud [0] @ 14064
# % Message delivered to ccfraud [0] @ 14065
# % Message delivered to ccfraud [0] @ 14066
# % Message delivered to ccfraud [0] @ 14067
# % Message delivered to ccfraud [0] @ 14070
# % Message delivered to ccfraud [0] @ 14071
# % Message delivered to ccfraud [0] @ 14072
# % Message delivered to ccfraud [0] @ 14073
# % Message delivered to ccfraud [0] @ 14074
# % Message delivered to ccfraud [0] @ 14075
# % Message delivered to ccfraud [0] @ 14076
# % Message delivered to ccfraud [0] @ 14077
# % Message delivered to ccfraud [0] @ 14100
# % Message delivered to ccfraud [0] @ 14101
# % Message delivered to ccfraud [0] @ 14102
# % Message delivered to ccfraud [0] @ 14103
# % Message delivered to ccfraud [0] @ 14104
# % Message delivered to ccfraud [0] @ 14105
# % Message delivered to ccfraud [0] @ 14106
# % Message delivered to ccfraud [0] @ 14107
# % Message delivered to ccfraud [0] @ 14110
# % Message delivered to ccfraud [0] @ 14111
# % Message delivered to ccfraud [0] @ 14112
# % Message delivered to ccfraud [0] @ 14113
# % Message delivered to ccfraud [0] @ 14114
# % Message delivered to ccfraud [0] @ 14115
# % Message delivered to ccfraud [0] @ 14116
# % Message delivered to ccfraud [0] @ 14117
# % Message delivered to ccfraud [0] @ 14120
# % Message delivered to ccfraud [0] @ 14121
# % Message delivered to ccfraud [0] @ 14122
# % Message delivered to ccfraud [0] @ 14123
# % Message delivered to ccfraud [0] @ 14124
# % Message delivered to ccfraud [0] @ 14125
# % Message delivered to ccfraud [0] @ 14126
# % Message delivered to ccfraud [0] @ 14127
# % Message delivered to ccfraud [0] @ 14130
